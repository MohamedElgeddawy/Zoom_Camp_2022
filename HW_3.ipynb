# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedElgeddawy/Zoom_Camp_2022/blob/main/HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Data preparation
# *   Download the data, read it with pandas
# * Look at the data
# * Make column names and values look uniform
#
# * Select only the features from above and fill in the missing values with 0.
#
# *  Create a new column rooms_per_household by dividing the column total_rooms by the column households from dataframe.
#
# *   List Create a new column bedrooms_per_room by dividing the column total_bedrooms by the column total_rooms from dataframe.
# *  Create a new column population_per_household by dividing the column population by the column households from dataframe.

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Out:
# --2022-09-26 13:40:08--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]   1.36M  --.-KB/s    in 0.04s
#
# 2022-09-26 13:40:09 (34.4 MB/s) - ‘housing.csv’ saved [1423529/1423529]

# %%
df = pd.read_csv('housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
#Select only the features from above and fill in the missing values with 0.

df["total_bedrooms"].fillna(0, inplace=True)

# %%
#Create a new column rooms_per_household by dividing the column total_rooms by the column households from dataframe.
df["rooms_per_household"] = df['total_rooms']/df['households']
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household
# 0             6.984127
# 1             6.238137
# 2             8.288136
# 3             5.817352
# 4             6.281853

# %%
#List Create a new column bedrooms_per_room by dividing the column total_bedrooms by the column total_rooms from dataframe.

df["bedrooms_per_room"] = df['total_rooms']/df['total_rooms']
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household  bedrooms_per_room
# 0             6.984127                1.0
# 1             6.238137                1.0
# 2             8.288136                1.0
# 3             5.817352                1.0
# 4             6.281853                1.0

# %%
#Create a new column population_per_household by dividing the column population by the column households from dataframe.
df["population_per_household"] = df['population']/df['households']
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household  bedrooms_per_room  population_per_household
# 0             6.984127                1.0                  2.555556
# 1             6.238137                1.0                  2.109842
# 2             8.288136                1.0                  2.802260
# 3             5.817352                1.0                  2.547945
# 4             6.281853                1.0                  2.181467

# %% [markdown]
# ##Question 1
# What is the most frequent observation (mode) for the column ocean_proximity?

# %%
# frequent observation (mode) for the column 'neighbourhood_group'
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df['ocean_proximity'].mode()
# Out:
# 0    <1H OCEAN
# dtype: object

# %% [markdown]
# Answer for Question_1 : '<1H OCEAN'

# %% [markdown]
# ##Question 2
# * Create the correlation matrix for the numerical features of your train dataset.
#    * In a correlation matrix, you compute the correlation coefficient between every pair of features in the dataset.
# * What are the two features that have the biggest correlation in this dataset?
# ###Options:
#
# * total_bedrooms and households
# * total_bedrooms and total_rooms
# * population and households
# * population_per_household and total_rooms

# %%
df_numeric = df.copy()
df_numeric = df.drop(["ocean_proximity"], axis=1)
df_numeric.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       532.476211   1425.476744    499.539680       3.870671
# std        422.678333   1132.462122    382.329753       1.899822
# min          0.000000      3.000000      1.000000       0.499900
# 25%        292.000000    787.000000    280.000000       2.563400
# 50%        431.000000   1166.000000    409.000000       3.534800
# 75%        643.250000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value  rooms_per_household  bedrooms_per_room  \
# count        20640.000000         20640.000000            20640.0
# mean        206855.816909             5.429000                1.0
# std         115395.615874             2.474173                0.0
# min          14999.000000             0.846154                1.0
# 25%         119600.000000             4.440716                1.0
# 50%         179700.000000             5.229129                1.0
# 75%         264725.000000             6.052381                1.0
# max         500001.000000           141.909091                1.0
#
#        population_per_household
# count              20640.000000
# mean                   3.070655
# std                   10.386050
# min                    0.692308
# 25%                    2.429741
# 50%                    2.818116
# 75%                    3.282261
# max                 1243.333333

# %%
df.corr()
# Out:
#                           longitude  latitude  housing_median_age  \
# longitude                  1.000000 -0.924664           -0.108197
# latitude                  -0.924664  1.000000            0.011173
# housing_median_age        -0.108197  0.011173            1.000000
# total_rooms                0.044568 -0.036100           -0.361262
# total_bedrooms             0.068082 -0.065318           -0.317063
# population                 0.099773 -0.108785           -0.296244
# households                 0.055310 -0.071035           -0.302916
# median_income             -0.015176 -0.079809           -0.119034
# median_house_value        -0.045967 -0.144160            0.105623
# rooms_per_household       -0.027540  0.106389           -0.153277
# bedrooms_per_room               NaN       NaN                 NaN
# population_per_household   0.002476  0.002366            0.013191
#
#                           total_rooms  total_bedrooms  population  households  \
# longitude                    0.044568        0.068082    0.099773    0.055310
# latitude                    -0.036100       -0.065318   -0.108785   -0.071035
# housing_median_age          -0.361262       -0.317063   -0.296244   -0.302916
# total_rooms                  1.000000        0.920196    0.857126    0.918484
# total_bedrooms               0.920196        1.000000    0.866266    0.966507
# population                   0.857126        0.866266    1.000000    0.907222
# households                   0.918484        0.966507    0.907222    1.000000
# median_income                0.198050       -0.007295    0.004834    0.013033
# median_house_value           0.134153        0.049148   -0.024650    0.065843
# rooms_per_household          0.133798        0.002717   -0.072213   -0.080598
# bedrooms_per_room                 NaN             NaN         NaN         NaN
# population_per_household    -0.024581       -0.028019    0.069863   -0.027309
#
#                           median_income  median_house_value  \
# longitude                     -0.015176           -0.045967
# latitude                      -0.079809           -0.144160
# housing_median_age            -0.119034            0.105623
# total_rooms                    0.198050            0.134153
# total_bedrooms                -0.007295            0.049148
# population                     0.004834           -0.024650
# households                     0.013033            0.065843
# median_income                  1.000000            0.688075
# median_house_value             0.688075            1.000000
# rooms_per_household            0.326895            0.151948
# bedrooms_per_room                   NaN                 NaN
# population_per_household       0.018766           -0.023737
#
#                           rooms_per_household  bedrooms_per_room  \
# longitude                           -0.027540                NaN
# latitude                             0.106389                NaN
# housing_median_age                  -0.153277                NaN
# total_rooms                          0.133798                NaN
# total_bedrooms                       0.002717                NaN
# population                          -0.072213                NaN
# households                          -0.080598                NaN
# median_income                        0.326895                NaN
# median_house_value                   0.151948                NaN
# rooms_per_household                  1.000000                NaN
# bedrooms_per_room                         NaN                NaN
# population_per_household            -0.004852                NaN
#
#                           population_per_household
# longitude                                 0.002476
# latitude                                  0.002366
# housing_median_age                        0.013191
# total_rooms                              -0.024581
# total_bedrooms                           -0.028019
# population                                0.069863
# households                               -0.027309
# median_income                             0.018766
# median_house_value                       -0.023737
# rooms_per_household                      -0.004852
# bedrooms_per_room                              NaN
# population_per_household                  1.000000

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)

# %%
plt.figure(figsize=(20,10))  
sns.heatmap(df_numeric.corr(),annot=True,linewidths=.5, cmap="Blues")
plt.title('Heatmap showing correlations between numerical data')
plt.show()

# %%
pd.set_option('display.max_rows', None)
df_numeric.corr().unstack().sort_values(ascending = False)
# Out:
# longitude                 longitude                   1.000000
# latitude                  latitude                    1.000000
# rooms_per_household       rooms_per_household         1.000000
# median_house_value        median_house_value          1.000000
# median_income             median_income               1.000000
# households                households                  1.000000
# total_bedrooms            total_bedrooms              1.000000
# total_rooms               total_rooms                 1.000000
# housing_median_age        housing_median_age          1.000000
# population                population                  1.000000
# population_per_household  population_per_household    1.000000
# households                total_bedrooms              0.966507
# total_bedrooms            households                  0.966507
# total_rooms               total_bedrooms              0.920196
# total_bedrooms            total_rooms                 0.920196
# total_rooms               households                  0.918484
# households                total_rooms                 0.918484
# population                households                  0.907222
# households                population                  0.907222
# total_bedrooms            population                  0.866266
# population                total_bedrooms              0.866266
#                           total_rooms                 0.857126
# total_rooms               population                  0.857126
# median_income             median_house_value          0.688075
# median_house_value        median_income               0.688075
# median_income             rooms_per_household         0.326895
# rooms_per_household       median_income               0.326895
# total_rooms               median_income               0.198050
# median_income             total_rooms                 0.198050
# rooms_per_household       median_house_value          0.151948
# median_house_value        rooms_per_household         0.151948
#                           total_rooms                 0.134153
# total_rooms               median_house_value          0.134153
# rooms_per_household       total_rooms                 0.133798
# total_rooms               rooms_per_household         0.133798
# latitude                  rooms_per_household         0.106389
# rooms_per_household       latitude                    0.106389
# median_house_value        housing_median_age          0.105623
# housing_median_age        median_house_value          0.105623
# population                longitude                   0.099773
# longitude                 population                  0.099773
# population_per_household  population                  0.069863
# population                population_per_household    0.069863
# total_bedrooms            longitude                   0.068082
# longitude                 total_bedrooms              0.068082
# median_house_value        households                  0.065843
# households                median_house_value          0.065843
# longitude                 households                  0.055310
# households                longitude                   0.055310
# total_bedrooms            median_house_value          0.049148
# median_house_value        total_bedrooms              0.049148
# longitude                 total_rooms                 0.044568
# total_rooms               longitude                   0.044568
# population_per_household  median_income               0.018766
# median_income             population_per_household    0.018766
# housing_median_age        population_per_household    0.013191
# population_per_household  housing_median_age          0.013191
# median_income             households                  0.013033
# households                median_income               0.013033
# housing_median_age        latitude                    0.011173
# latitude                  housing_median_age          0.011173
# population                median_income               0.004834
# median_income             population                  0.004834
# total_bedrooms            rooms_per_household         0.002717
# rooms_per_household       total_bedrooms              0.002717
# population_per_household  longitude                   0.002476
# longitude                 population_per_household    0.002476
# population_per_household  latitude                    0.002366
# latitude                  population_per_household    0.002366
# population_per_household  rooms_per_household        -0.004852
# rooms_per_household       population_per_household   -0.004852
# median_income             total_bedrooms             -0.007295
# total_bedrooms            median_income              -0.007295
# median_income             longitude                  -0.015176
# longitude                 median_income              -0.015176
# population_per_household  median_house_value         -0.023737
# median_house_value        population_per_household   -0.023737
# total_rooms               population_per_household   -0.024581
# population_per_household  total_rooms                -0.024581
# population                median_house_value         -0.024650
# median_house_value        population                 -0.024650
# population_per_household  households                 -0.027309
# households                population_per_household   -0.027309
# rooms_per_household       longitude                  -0.027540
# longitude                 rooms_per_household        -0.027540
# population_per_household  total_bedrooms             -0.028019
# total_bedrooms            population_per_household   -0.028019
# latitude                  total_rooms                -0.036100
# total_rooms               latitude                   -0.036100
# median_house_value        longitude                  -0.045967
# longitude                 median_house_value         -0.045967
# total_bedrooms            latitude                   -0.065318
# latitude                  total_bedrooms             -0.065318
# households                latitude                   -0.071035
# latitude                  households                 -0.071035
# population                rooms_per_household        -0.072213
# rooms_per_household       population                 -0.072213
# latitude                  median_income              -0.079809
# median_income             latitude                   -0.079809
# rooms_per_household       households                 -0.080598
# households                rooms_per_household        -0.080598
# housing_median_age        longitude                  -0.108197
# longitude                 housing_median_age         -0.108197
# latitude                  population                 -0.108785
# population                latitude                   -0.108785
# median_income             housing_median_age         -0.119034
# housing_median_age        median_income              -0.119034
# latitude                  median_house_value         -0.144160
# median_house_value        latitude                   -0.144160
# rooms_per_household       housing_median_age         -0.153277
# housing_median_age        rooms_per_household        -0.153277
#                           population                 -0.296244
# population                housing_median_age         -0.296244
# households                housing_median_age         -0.302916
# housing_median_age        households                 -0.302916
# total_bedrooms            housing_median_age         -0.317063
# housing_median_age        total_bedrooms             -0.317063
#                           total_rooms                -0.361262
# total_rooms               housing_median_age         -0.361262
# latitude                  longitude                  -0.924664
# longitude                 latitude                   -0.924664
#                           bedrooms_per_room                NaN
# latitude                  bedrooms_per_room                NaN
# housing_median_age        bedrooms_per_room                NaN
# total_rooms               bedrooms_per_room                NaN
# total_bedrooms            bedrooms_per_room                NaN
# population                bedrooms_per_room                NaN
# households                bedrooms_per_room                NaN
# median_income             bedrooms_per_room                NaN
# median_house_value        bedrooms_per_room                NaN
# rooms_per_household       bedrooms_per_room                NaN
# bedrooms_per_room         longitude                        NaN
#                           latitude                         NaN
#                           housing_median_age               NaN
#                           total_rooms                      NaN
#                           total_bedrooms                   NaN
#                           population                       NaN
#                           households                       NaN
#                           median_income                    NaN
#                           median_house_value               NaN
#                           rooms_per_household              NaN
#                           bedrooms_per_room                NaN
#                           population_per_household         NaN
# population_per_household  bedrooms_per_room                NaN
# dtype: float64

# %% [markdown]
# Answer for Question_2 : households & total_bedrooms

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'rooms_per_household',
#        'bedrooms_per_room', 'population_per_household'],
#       dtype='object')

# %% [markdown]
# ###Make median_house_value binary
# * We need to turn the median_house_value variable from numeric into binary.
# * Let's create a variable above_average which is 1 if the median_house_value is above its mean value and 0 otherwise.

# %%
data_class = df.copy()
mean = data_class['median_house_value'].mean()

data_class['above_average'] = np.where(data_class['median_house_value']>=mean,1,0)
data_class = data_class.drop('median_house_value', axis=1)

# %% [markdown]
# ###Split the data
# * Split your data in train/val/test sets, with 60%/20%/20% distribution.
# U* se Scikit-Learn for that (the train_test_split function) and set the seed to 42.
# * Make sure that the target value (median_house_value) is not in your dataframe.

# %%
from sklearn.model_selection import train_test_split
df_train_full, df_test = train_test_split(data_class, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=42)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.above_average.values
y_val = df_val.above_average.values
y_test = df_test.above_average.values

# %% [markdown]
# ##Question 3
# * Calculate the mutual information score with the (binarized) price for the categorical variable that we have. Use the training set only.
# * What is the value of mutual information?
# * Round it to 2 decimal digits using round(score, 2)

# %%
from sklearn.metrics import mutual_info_score

# %%
cat = ['ocean_proximity']

# %%
def calculate_mi(series):
    return mutual_info_score(series, df_train.above_average)

df_mi = df_train[cat].apply(calculate_mi)
df_mi = df_mi.sort_values(ascending=False).to_frame(name='MI')

# %%
df_mi
# Out:
#                        MI
# ocean_proximity  0.101384

# %% [markdown]
# ##Question 4
# * Now let's train a logistic regression
# * Remember that we have one categorical variable ocean_proximity in the data.Include it using one-hot encoding.
# * Fit the model on the training dataset.
#    * To make sure the results are reproducible across different versions of Scikit-Learn, fit the model with these parameters:
#    * model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)
# * Calculate the accuracy on the validation dataset and round it to 2 decimal digits.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
num = ['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income','rooms_per_household',
       'bedrooms_per_room', 'population_per_household']

# %%
train_dict = df_train[cat + num].to_dict(orient='records')

dv = DictVectorizer(sparse=False)
dv.fit(train_dict)

X_train = dv.transform(train_dict)

# %%
model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)

val_dict = df_val[cat + num].to_dict(orient='records')
X_val = dv.transform(val_dict)

y_pred = model.predict(X_val)

accuracy = np.round(accuracy_score(y_val, y_pred),2)
print("acc",accuracy)
# Out:
# acc 0.84

# %% [markdown]
# ##Question 5
# * Let's find the least useful feature using the feature elimination technique.
# * Train a model with all these features (using the same parameters as in Q4).
# * Now exclude each feature from this set and train a model without it. Record the accuracy for each model.
# * For each feature, calculate the difference between the original accuracy and the accuracy without the feature.
# * Which of following feature has the smallest difference?
#   * total_rooms
#   * total_bedrooms
#   * population
#   * households

# %%
features = cat + num
features
# Out:
# ['ocean_proximity',
#  'longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'rooms_per_household',
#  'bedrooms_per_room',
#  'population_per_household']

# %%
#Feature elimination
orig_score = accuracy


for c in features:
    subset = features.copy()
    subset.remove(c)
    
    train_dict = df_train[subset].to_dict(orient='records')

    dv = DictVectorizer(sparse=False)
    dv.fit(train_dict)

    X_train = dv.transform(train_dict)

    model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)
    model.fit(X_train, y_train)

    val_dict = df_val[subset].to_dict(orient='records')
    X_val = dv.transform(val_dict)

    y_pred = model.predict(X_val)

    score = accuracy_score(y_val, y_pred)
    print(c, orig_score - score, score)
# Out:
# ocean_proximity 0.019263565891472822 0.8207364341085271
# longitude 0.007393410852713167 0.8326065891472868
# latitude 0.007635658914728616 0.8323643410852714
# housing_median_age 0.008846899224806193 0.8311531007751938
# total_rooms 0.0027906976744185297 0.8372093023255814
# total_bedrooms 0.004486434108527115 0.8355135658914729
# population 0.01344961240310072 0.8265503875968992
# households 0.005939922480620141 0.8340600775193798
# median_income 0.05511627906976746 0.7848837209302325
# rooms_per_household 0.004486434108527115 0.8355135658914729
# bedrooms_per_room 0.004486434108527115 0.8355135658914729
# population_per_household 0.004001937984496107 0.8359980620155039

# %% [markdown]
# ##Question 6
# * For this question, we'll see how to use a linear regression model from Scikit-Learn
# * We'll need to use the original column 'median_house_value'. Apply the logarithmic transformation to this column.
# * Fit the Ridge regression model (model = Ridge(alpha=a, solver="sag", random_state=42)) on the training data.
# * This model has a parameter alpha. Let's try the following values: [0, 0.01, 0.1, 1, 10]
# * Which of these alphas leads to the best RMSE on the validation set? Round your RMSE scores to 3 decimal digits.
#
# If there are multiple options, select the smallest alpha.

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'rooms_per_household',
#        'bedrooms_per_room', 'population_per_household'],
#       dtype='object')

# %%
df['median_house_value']=np.log1p(df['median_house_value'])

# %%
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=42)
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.median_house_value.values
y_val = df_val.median_house_value.values
y_test = df_test.median_house_value.values
del df_train['median_house_value']
del df_val['median_house_value']
del df_test['median_house_value']

# %% [markdown]
# ####Ridge Regression

# %%
train_dict = df_train[cat + num].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)
dv.fit(train_dict)

X_train = dv.transform(train_dict)

val_dict = df_val[cat + num].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
for a in [0, 0.01, 0.1, 1, 10]:
    model = Ridge(alpha=a,random_state=42)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    
    score = np.sqrt(mean_squared_error(y_val, y_pred))
    
    print(a, round(score, 3))
# Out:
# 0 0.342
# 0.01 0.325
# 0.1 0.325
# 1 0.325
# 10 0.325
